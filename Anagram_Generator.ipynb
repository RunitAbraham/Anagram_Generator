# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.corpus import cmudict
from collections import defaultdict

# Download the required NLTK resources
# nltk.download('wordnet')
# nltk.download('cmudict')

# %%
def is_trivial_variation(word1, word2):
    # Filter out possessive forms and common British vs. American spellings 
    # Not complete
    trivial_pairs = {('theater', 'theatre'), ('center', 'centre'), ('color', 'colour'),
                     ('flavor', 'flavour'), ('honor', 'honour'), ('rumor', 'rumour')}
    if word1.endswith("'s") or word2.endswith("'s") or word1.endswith("s'") or word2.endswith("s'"):
        return True
    if (word1, word2) in trivial_pairs or (word2, word1) in trivial_pairs:
        return True
    return False

def get_related_words(word):
    # Include synonyms, hypernyms, hyponyms, and derivationally related forms
    # Antonyms pending
    related_words = set()
    for synset in wn.synsets(word):
        related_words.update(lemma.name().replace('_', ' ') for lemma in synset.lemmas())
        related_words.update(lemma.name().replace('_', ' ') for hyper in synset.hypernyms() for lemma in hyper.lemmas())
        related_words.update(lemma.name().replace('_', ' ') for hypo in synset.hyponyms() for lemma in hypo.lemmas())
        related_words.update(lemma.name().replace('_', ' ') for lemma in synset.lemmas() for form in lemma.derivationally_related_forms())
    return related_words

def are_phonetically_similar(word1, word2, cmu_dict):
    # Check for phonetic similarity using CMU Pronouncing Dictionary
    pron1 = {tuple(phonemes) for phonemes in cmu_dict.get(word1, [])}
    pron2 = {tuple(phonemes) for phonemes in cmu_dict.get(word2, [])}
    return bool(pron1 & pron2)

# %%
class Node:
    """
    Represents a single node within the Anatree.
    
    Attributes:
        children (dict): A dictionary mapping characters to Node objects.
        word_end (bool): A flag indicating whether a word ends at this node.
        words (list): A list of complete words that terminate at this node.
    """
    def __init__(self):
        self.children = {}  # Initialize the children as an empty dictionary.
        self.word_end = False  # Initially, this node is not the end of any word.
        self.words = []  # Initialize an empty list to store words ending at this node.

class Anatree:
    """
    Represents the anagram tree (trie structure) used to store words in a way that
    facilitates the search for anagrams.
    
    The tree is built such that each path from the root to a word-end node represents
    a sorted sequence of characters from one or more words.

    Attributes:
        root (Node): The root node of the tree.
    """
    def __init__(self):
        self.root = Node()  # Start with a single root node.

    def insert(self, word):
        """
        Inserts a word into the Anatree. The characters of the word are sorted
        and used to navigate or expand the tree.

        Args:
            word (str): The word to be inserted into the tree.
        """
        node = self.root  # Start at the root of the tree.
        for char in sorted(word):  # Sort the word to treat anagrams the same.
            if char not in node.children:  # If char is not a child, add a new node.
                node.children[char] = Node()
            node = node.children[char]  # Move to the corresponding child node.
        node.word_end = True  # Mark that a word ends at this node.
        node.words.append(word)  # Add the original word to the node.

    def search_anagrams(self, word):
        """
        Searches for anagrams of a given word in the Anatree.

        Args:
            word (str): The word whose anagrams are to be found.

        Returns:
            list: A list of anagrams of the given word, if any exist.
        """
        node = self.root  # Start at the root of the tree.
        for char in sorted(word):  # Use sorted characters to search.
            if char in node.children:
                node = node.children[char]  # Move to the next node in the path.
            else:
                return []  # If any character is missing, no anagrams exist.
        return node.words if node.word_end else []  # Return words if it's a word-end node.

# %%
def process_anagrams(anatree, cmu_dict):
    """Process all words in the CMU dictionary to find all, semantic, and phonetic anagrams."""
    all_anagrams = defaultdict(list)
    semantic_anagrams = defaultdict(list)
    phonetic_anagrams = defaultdict(list)

    # Iterate over each word in the CMU dictionary
    for word in cmu_dict.keys():
        word_lower = word.lower()
        anagrams = anatree.search_anagrams(word_lower)

        # Collect all anagrams for each word, excluding the word itself
        filtered_anagrams = [anagram for anagram in anagrams if anagram != word_lower]
        if len(filtered_anagrams) > 0:  # Store only if there are other anagrams
            all_anagrams[word_lower] = filtered_anagrams

        related_words = get_related_words(word_lower)

        # Evaluate semantic and phonetic relationships among the anagrams
        for anagram in anagrams:
            if anagram != word_lower and not is_trivial_variation(word_lower, anagram):
                if anagram in related_words:
                    semantic_anagrams[word_lower].append(anagram)
                if are_phonetically_similar(word_lower, anagram, cmu_dict):
                    phonetic_anagrams[word_lower].append(anagram)

    return all_anagrams, semantic_anagrams, phonetic_anagrams

# Load CMU Pronouncing Dictionary
cmu_dict = cmudict.dict()

# Create an Anatree and insert words
anatree = Anatree()
for word in cmu_dict.keys():
    anatree.insert(word.lower())

# Using the function to find anagrams
all_anagrams, semantic_similar_anagrams, phonetic_similar_anagrams = process_anagrams(anatree, cmu_dict)

# %%
# Print some anagrams to verify
print("All Anagrams:")
for key, value in list(all_anagrams.items())[:10]:
    print(f"{key}: {value}")

print("\nSemantic Similar Anagrams:")
for key, value in list(semantic_similar_anagrams.items())[:10]:
    print(f"{key}: {value}")

print("\nPhonetic Similar Anagrams:")
for key, value in list(phonetic_similar_anagrams.items())[:-10]:
    print(f"{key}: {value}")
# Out:
# All Anagrams:
# aachen: ['eachan']
# aamodt: ['damato']
# aancor: ['carano']
# aardema: ['amerada']
# aaron: ['anora']
# aarti: ['atari', 'atria', 'taira', 'tiara']
# aase: ['asea']
# aasen: ['asean', 'enasa']
# aback: ['baack']
# abad: ['bada']
#
# Semantic Similar Anagrams:
# accouterment: ['accoutrement']
# accoutrement: ['accouterment']
# amphitheater: ['amphitheatre']
# amphitheatre: ['amphitheater']
# angered: ['enraged']
# ate: ['eat']
# bate: ['beat']
# beat: ['bate']
# beats: ['baste']
# being: ['begin']
#
# Phonetic Similar Anagrams:
# abel: ['able']
# abels: ['ables']
# able: ['abel']
# ables: ['abels']
# accouterment: ['accoutrement']
# accouterments: ['accoutrements']
# accoutrement: ['accouterment']
# accoutrements: ['accouterments']
# ack: ['akc']
# aires: ['aries']
# akc: ['ack']
# aker: ['akre']
# akre: ['aker']
# aleen: ['alene']
# alene: ['aleen']
# appel: ['apple']
# appelbaum: ['applebaum']
# appelman: ['appleman']
# apple: ['appel']
# applebaum: ['appelbaum']
# appleman: ['appelman']
# aries: ['aires']
# axel: ['axle']
# axle: ['axel']
# baek: ['beak']
# baer: ['bare', 'bear']
# bahn: ['banh']
# banh: ['bahn']
# bankrupcty: ['bankruptcy']
# bankruptcy: ['bankrupcty']
# barber: ['barbre']
# barbre: ['barber']
# bare: ['baer', 'bear']
# bares: ['bears']
# bartel: ['bartle']
# bartels: ['bartles']
# bartle: ['bartel']
# bartles: ['bartels']
# bayes: ['bayse']
# bayse: ['bayes']
# beak: ['baek']
# bear: ['baer', 'bare']
# bears: ['bares']
# beer: ['bere']
# beil: ['biel']
# beilke: ['bielke']
# bein: ['bien']
# beit: ['bite']
# beitz: ['bietz']
# bere: ['beer']
# beseiged: ['besieged']
# besieged: ['beseiged']
# bickel: ['bickle']
# bickle: ['bickel']
# biel: ['beil']
# bielke: ['beilke']
# bien: ['bein']
# bies: ['bise']
# bietz: ['beitz']
# bindel: ['bindle']
# bindle: ['bindel']
# bingel: ['bingle']
# bingle: ['bingel']
# bise: ['bies']
# bite: ['beit']
# bittel: ['bittle']
# bittle: ['bittel']
# bleu: ['blue']
# bloem: ['blome']
# blome: ['bloem']
# blue: ['bleu']
# boen: ['bone']
# boer: ['bore']
# boers: ['bores']
# boes: ['bose']
# bone: ['boen']
# bore: ['boer']
# bores: ['boers']
# bose: ['boes']
# bottel: ['bottle']
# bottle: ['bottel']
# brake: ['break']
# brakefield: ['breakfield']
# brakes: ['breaks']
# brandel: ['brandle']
# brandle: ['brandel']
# break: ['brake']
# breakfield: ['brakefield']
# breaks: ['brakes']
# brede: ['breed']
# breed: ['brede']
# brendel: ['brendle']
# brendle: ['brendel']
# brickel: ['brickle']
# brickle: ['brickel']
# bruen: ['brune']
# brune: ['bruen']
# buckel: ['buckle']
# buckels: ['buckles']
# buckle: ['buckel']
# buckles: ['buckels']
# burkel: ['burkle']
# burkle: ['burkel']
# camber: ['cambre']
# cambre: ['camber']
# capel: ['caple']
# caple: ['capel']
# centers: ['centres']
# centres: ['centers']
# chappel: ['chapple']
# chapple: ['chappel']
# cindy: ['cyndi']
# code: ['coed']
# coed: ['code']
# commercial: ['commerical']
# commerical: ['commercial']
# conkel: ['conkle']
# conkle: ['conkel']
# coppel: ['copple']
# copple: ['coppel']
# crackel: ['crackle']
# crackle: ['crackel']
# cries: ['crise']
# crise: ['cries']
# cude: ['cued']
# cued: ['cude']
# cyndi: ['cindy']
# darleen: ['darlene']
# darlene: ['darleen']
# dede: ['deed']
# deed: ['dede']
# deidre: ['diedre']
# deion: ['dione']
# deitz: ['dietz']
# densely: ['densley']
# densley: ['densely']
# diedre: ['deidre']
# dies: ['dise']
# dietz: ['deitz']
# dingel: ['dingle']
# dingle: ['dingel']
# dione: ['deion']
# dippel: ['dipple']
# dipple: ['dippel']
# dirkes: ['dirkse']
# dirkse: ['dirkes']
# discreet: ['discrete']
# discrete: ['discreet']
# dise: ['dies']
# dunkel: ['dunkle']
# dunkelberger: ['dunkleberger']
# dunkle: ['dunkel']
# dunkleberger: ['dunkelberger']
# ebel: ['eble']
# eble: ['ebel']
# eckels: ['eckles']
# eckles: ['eckels']
# edelman: ['edleman']
# edleman: ['edelman']
# eid: ['ide']
# eir: ['ire']
# eis: ['ise']
# eisman: ['iseman']
# eleen: ['elene']
# elene: ['eleen']
# enders: ['endres']
# endres: ['enders']
# eppel: ['epple']
# epple: ['eppel']
# ertel: ['ertle']
# ertle: ['ertel']
# eshelman: ['eshleman']
# eshleman: ['eshelman']
# faber: ['fabre']
# fabre: ['faber']
# farren: ['ferran']
# faver: ['favre']
# favre: ['faver']
# fede: ['feed']
# feed: ['fede']
# feil: ['fiel']
# feild: ['field']
# fein: ['fine']
# feinberg: ['fineberg']
# feinman: ['fineman']
# feit: ['fite']
# ferran: ['farren']
# fiber: ['fibre']
# fiberboard: ['fibreboard']
# fibre: ['fiber']
# fibreboard: ['fiberboard']
# fickel: ['fickle']
# fickle: ['fickel']
# fiel: ['feil']
# field: ['feild']
# fine: ['fein']
# fineberg: ['feinberg']
# fineman: ['feinman']
# finkel: ['finkle']
# finkle: ['finkel']
# fite: ['feit']
# floersheim: ['floresheim']
# floresheim: ['floersheim']
# fluet: ['flute']
# flute: ['fluet']
# fogel: ['fogle']
# fogelman: ['fogleman']
# fogle: ['fogel']
# fogleman: ['fogelman']
# footware: ['footwear']
# footwear: ['footware']
# foret: ['forte']
# forte: ['foret']
# fraiser: ['frasier']
# fraizer: ['frazier']
# frasier: ['fraiser']
# frazier: ['fraizer']
# fread: ['freda']
# freda: ['fread']
# frede: ['freed']
# freed: ['frede']
# frees: ['frese']
# freid: ['fried']
# freidan: ['friedan']
# freidman: ['friedman']
# freiman: ['frieman']
# frese: ['frees']
# fried: ['freid']
# friedan: ['freidan']
# friedman: ['freidman']
# frieman: ['freiman']
# gadhafi: ['ghadafi']
# gael: ['gale']
# gahli: ['ghali']
# gale: ['gael']
# gandhi: ['ghandi']
# geer: ['gere']
# gehrig: ['gherig']
# geil: ['gile']
# gere: ['geer']
# gettel: ['gettle']
# gettle: ['gettel']
# ghadafi: ['gadhafi']
# ghali: ['gahli']
# ghandi: ['gandhi']
# gherig: ['gehrig']
# gile: ['geil']
# giron: ['gorin']
# gittelman: ['gittleman']
# gittleman: ['gittelman']
# gobel: ['goble']
# goble: ['gobel']
# goes: ['gose']
# gorin: ['giron']
# gose: ['goes']
# grate: ['great']
# grates: ['greats']
# great: ['grate']
# greats: ['grates']
# grede: ['greed']
# greed: ['grede']
# greet: ['grete']
# greif: ['grief']
# grete: ['greet']
# grief: ['greif']
# gries: ['grise']
# grise: ['gries']
# groen: ['grone']
# groep: ['grope']
# grone: ['groen']
# grope: ['groep']
# gundel: ['gundle']
# gundle: ['gundel']
# hackel: ['hackle']
# hackle: ['hackel']
# hainey: ['haynie']
# hamer: ['hamre']
# hampel: ['hample']
# hample: ['hampel']
# hamre: ['hamer']
# handel: ['handle']
# handels: ['handles']
# handle: ['handel']
# handles: ['handels']
# harte: ['heart']
# hartel: ['hartle']
# hartle: ['hartel']
# hassel: ['hassle']
# hassle: ['hassel']
# hayes: ['hayse']
# haynie: ['hainey']
# hayse: ['hayes']
# hazel: ['hazle']
# hazelton: ['hazleton']
# hazelwood: ['hazlewood']
# hazle: ['hazel']
# hazleton: ['hazelton']
# hazlewood: ['hazelwood']
# heart: ['harte']
# hebe: ['heeb']
# heckel: ['heckle']
# heckle: ['heckel']
# heeb: ['hebe']
# heid: ['hide']
# heil: ['hile']
# heilman: ['hileman']
# heim: ['hime']
# heims: ['himes']
# hein: ['hine']
# heinly: ['hinely']
# heins: ['hines']
# heit: ['hite']
# henkel: ['henkle']
# henkle: ['henkel']
# hickel: ['hickle']
# hickle: ['hickel']
# hide: ['heid']
# hier: ['hire']
# hile: ['heil']
# hileman: ['heilman']
# hime: ['heim']
# himes: ['heims']
# hine: ['hein']
# hinely: ['heinly']
# hines: ['heins']
# hinkel: ['hinkle']
# hinkle: ['hinkel']
# hire: ['hier']
# hite: ['heit']
# hoek: ['hoke']
# hoel: ['hole']
# hoen: ['hone']
# hoerner: ['hornere']
# hoes: ['hose']
# hoke: ['hoek']
# holde: ['holed']
# hole: ['hoel']
# holed: ['holde']
# hone: ['hoen']
# hoppel: ['hopple']
# hopple: ['hoppel']
# hornere: ['hoerner']
# horsely: ['horsley']
# horsley: ['horsely']
# hose: ['hoes']
# hottel: ['hottle']
# hottle: ['hottel']
# howes: ['howse']
# howse: ['howes']
# hren: ['rehn']
# hron: ['rohn']
# hsu: ['shu']
# hues: ['huse']
# hufnagel: ['hufnagle']
# hufnagle: ['hufnagel']
# humphery: ['humphrey']
# humphrey: ['humphery']
# huse: ['hues']
# hwang: ['whang']
# ide: ['eid']
# ingels: ['ingles']
# ingles: ['ingels']
# ire: ['eir']
# ise: ['eis']
# iseman: ['eisman']
# joens: ['jones']
# jonathon: ['jonothan']
# jones: ['joens']
# jonothan: ['jonathon']
# juel: ['jule']
# jule: ['juel']
# jungels: ['jungles']
# jungles: ['jungels']
# kael: ['kale']
# kahn: ['khan']
# kale: ['kael']
# kehm: ['khem']
# keifer: ['kiefer']
# keiffer: ['kieffer']
# keil: ['kiel']
# keiner: ['kiener']
# keiper: ['kieper']
# kembel: ['kemble']
# kemble: ['kembel']
# kempel: ['kemple']
# kemple: ['kempel']
# keppel: ['kepple']
# kepple: ['keppel']
# kessel: ['kessle']
# kessle: ['kessel']
# khan: ['kahn']
# khem: ['kehm']
# kibbel: ['kibble']
# kibble: ['kibbel']
# kiefer: ['keifer']
# kieffer: ['keiffer']
# kiel: ['keil']
# kiener: ['keiner']
# kieper: ['keiper']
# kimbel: ['kimble']
# kimble: ['kimbel']
# kimpel: ['kimple']
# kimple: ['kimpel']
# kindel: ['kindle']
# kindle: ['kindel']
# kinkel: ['kinkle']
# kinkle: ['kinkel']
# kittel: ['kittle']
# kittle: ['kittel']
# kleiman: ['klieman']
# klein: ['kline']
# kleinfelter: ['klinefelter']
# klieman: ['kleiman']
# kline: ['klein']
# klinefelter: ['kleinfelter']
# kneip: ['kniep']
# kniep: ['kneip']
# knippel: ['knipple']
# knipple: ['knippel']
# knittel: ['knittle']
# knittle: ['knittel']
# knobel: ['knoble']
# knoble: ['knobel']
# knodel: ['knodle']
# knodle: ['knodel']
# kobel: ['koble']
# koble: ['kobel']
# koehn: ['kohne']
# koep: ['kope']
# kohne: ['koehn']
# konkel: ['konkle']
# konkle: ['konkel']
# kope: ['koep']
# koppel: ['kopple']
# kopple: ['koppel']
# kreig: ['krieg']
# krieg: ['kreig']
# kuehnel: ['kuehnle']
# kuehnle: ['kuehnel']
# kunkel: ['kunkle']
# kunkle: ['kunkel']
# lahey: ['leahy']
# laureen: ['laurene']
# laurene: ['laureen']
# layhee: ['leahey']
# leahey: ['layhee']
# leahy: ['lahey']
# lebel: ['leble']
# leble: ['lebel']
# leboeuf: ['lebouef']
# lebouef: ['leboeuf']
# leen: ['lene']
# leep: ['lepe']
# lefeber: ['lefebre']
# lefebre: ['lefeber']
# lefever: ['lefevre']
# lefevre: ['lefever']
# leib: ['lieb']
# leiber: ['lieber']
# leibler: ['liebler']
# leibman: ['liebman']
# leif: ['lief']
# lein: ['lien']
# leinberger: ['lineberger']
# leins: ['liens']
# leitz: ['lietz']
# lene: ['leen']
# lepe: ['leep']
# leper: ['lepre']
# lepre: ['leper']
# leu: ['lue']
# lide: ['lied']
# lieb: ['leib']
# lieber: ['leiber']
# liebler: ['leibler']
# liebman: ['leibman']
# lied: ['lide']
# lief: ['leif']
# lien: ['lein']
# liens: ['leins']
# lies: ['lise']
# lietz: ['leitz']
# lineberger: ['leinberger']
# lise: ['lies']
# lobe: ['loeb']
# loeb: ['lobe']
# loew: ['lowe']
# loews: ['lowes']
# loewy: ['lowey']
# lowe: ['loew']
# lowes: ['loews']
# lowey: ['loewy']
# lue: ['leu']
# luster: ['lustre']
# lustre: ['luster']
# mabel: ['mable']
# mabey: ['maybe']
# mable: ['mabel']
# macbeth: ['mcbeath']
# macpherson: ['mcphearson']
# maes: ['mase']
# maley: ['mayle']
# mandel: ['mandle']
# mandle: ['mandel']
# mantel: ['mantle']
# mantle: ['mantel']
# markel: ['markle']
# markle: ['markel']
# mase: ['maes']
# maybe: ['mabey']
# mayes: ['mayse']
# mayle: ['maley']
# mayse: ['mayes']
# mcbeath: ['macbeth']
# mccaffery: ['mccaffrey']
# mccaffrey: ['mccaffery']
# mccluer: ['mcclure']
# mcclure: ['mccluer']
# mccorkel: ['mccorkle']
# mccorkle: ['mccorkel']
# mccrae: ['mccrea']
# mccrea: ['mccrae']
# mccuen: ['mccune']
# mccune: ['mccuen']
# mcfarren: ['mcferran']
# mcferran: ['mcfarren']
# mclane: ['mclean']
# mclean: ['mclane']
# mcneil: ['mcniel']
# mcniel: ['mcneil']
# mcphearson: ['macpherson']
# meet: ['mete']
# mein: ['mien']
# meiner: ['mineer']
# meinhart: ['minehart']
# meredith: ['merideth']
# merideth: ['meredith']
# merkel: ['merkle']
# merkle: ['merkel']
# mester: ['mestre']
# mestre: ['mester']
# mete: ['meet']
# michael: ['micheal']
# micheal: ['michael']
# mickel: ['mickle']
# mickels: ['mickles']
# mickle: ['mickel']
# mickles: ['mickels']
# mien: ['mein']
# mier: ['mire']
# mihn: ['minh']
# mineer: ['meiner']
# minehart: ['meinhart']
# minh: ['mihn']
# mire: ['mier']
# miter: ['mitre']
# mitre: ['miter']
# mittelman: ['mittleman']
# mittelstaedt: ['mittelsteadt']
# mittelsteadt: ['mittelstaedt']
# mittleman: ['mittelman']
# moen: ['mone']
# moes: ['mose']
# mogel: ['mogle']
# mogle: ['mogel']
# mone: ['moen']
# mose: ['moes']
# mosel: ['mosle']
# mosely: ['mosley']
# mosle: ['mosel']
# mosley: ['mosely']
# naeve: ['neave']
# nagel: ['nagle']
# nagle: ['nagel']
# neave: ['naeve']
# needelman: ['needleman']
# needleman: ['needelman']
# neice: ['niece']
# neider: ['nieder']
# neil: ['niel']
# neild: ['nield']
# neils: ['niels']
# neilson: ['nielson']
# neiman: ['nieman']
# neiss: ['niess']
# nickel: ['nickle']
# nickels: ['nickles']
# nickle: ['nickel']
# nickles: ['nickels']
# niece: ['neice']
# nieder: ['neider']
# niel: ['neil']
# nield: ['neild']
# niels: ['neils']
# nielson: ['neilson']
# nieman: ['neiman']
# niess: ['neiss']
# noes: ['nose']
# nose: ['noes']
# o'hallaron: ["o'halloran"]
# o'halloran: ["o'hallaron"]
# opel: ['ople']
# ople: ['opel']
# paek: ['peak']
# pare: ['pear']
# pares: ['pears']
# peak: ['paek']
# pear: ['pare']
# pearlstein: ['pearlstine']
# pearlstine: ['pearlstein']
# pears: ['pares']
# peet: ['pete']
# peil: ['piel']
# peirce: ['pierce']
# peitz: ['pietz']
# peppel: ['pepple']
# pepple: ['peppel']
# permanente: ['permenante']
# permenante: ['permanente']
# pete: ['peet']
# petit: ['petti']
# petitt: ['pettit']
# petti: ['petit']
# pettit: ['petitt']
# pharaoh: ['pharoah']
# pharaohs: ['pharoahs']
# pharoah: ['pharaoh']
# pharoahs: ['pharaohs']
# pickel: ['pickle']
# pickle: ['pickel']
# piel: ['peil']
# pierce: ['peirce']
# pietz: ['peitz']
# pouter: ['poutre']
# poutre: ['pouter']
# precede: ['preceed']
# precedes: ['preceeds']
# preceed: ['precede']
# preceeds: ['precedes']
# preuss: ['pruess']
# pride: ['pried']
# pried: ['pride']
# pruess: ['preuss']
# pyhrric: ['pyrrhic']
# pyrrhic: ['pyhrric']
# rae: ['rea']
# raffel: ['raffle']
# raffle: ['raffel']
# ragel: ['ragle']
# ragle: ['ragel']
# rah: ['rha']
# rahn: ['ranh']
# randel: ['randle']
# randle: ['randel']
# ranh: ['rahn']
# rateliff: ['ratliffe']
# ratliffe: ['rateliff']
# raye: ['reay']
# rea: ['rae']
# reay: ['raye']
# reeh: ['rhee']
# rehm: ['rhem']
# rehn: ['hren']
# reichel: ['reichle']
# reichle: ['reichel']
# reick: ['rieck']
# reid: ['ried']
# reider: ['rieder']
# reiders: ['rieders']
# reidy: ['riedy']
# reif: ['rief']
# reigle: ['riegel', 'riegle']
# reily: ['riely']
# reinhardt: ['rinehardt']
# reinhart: ['rinehart']
# reit: ['rite']
# reits: ['rites']
# reul: ['ruel', 'rule']
# reuss: ['ruess']
# reust: ['ruest']
# rha: ['rah']
# rhee: ['reeh']
# rhein: ['rhine']
# rhem: ['rehm']
# rhin: ['rihn']
# rhine: ['rhein']
# rho: ['roh']
# rhode: ['rohde']
# rhome: ['roehm']
# rhorer: ['rohrer']
# rickels: ['rickles']
# rickles: ['rickels']
# ridgely: ['ridgley']
# ridgley: ['ridgely']
# rieck: ['reick']
# ried: ['reid']
# rieder: ['reider']
# rieders: ['reiders']
# riedy: ['reidy']
# rief: ['reif']
# riegel: ['reigle', 'riegle']
# riegle: ['reigle', 'riegel']
# riely: ['reily']
# ries: ['rise']
# riffel: ['riffle']
# riffle: ['riffel']
# rihn: ['rhin']
# rinehardt: ['reinhardt']
# rinehart: ['reinhart']
# ringel: ['ringle']
# ringle: ['ringel']
# rippel: ['ripple']
# ripple: ['rippel']
# rise: ['ries']
# rite: ['reit']
# rites: ['reits']
# robel: ['roble']
# roble: ['robel']
# rode: ['roed']
# roed: ['rode']
# roehm: ['rhome']
# roell: ['rolle']
# roen: ['rone']
# roes: ['rose']
# roh: ['rho']
# rohde: ['rhode']
# rohn: ['hron']
# rohrer: ['rhorer']
# rolle: ['roell']
# rone: ['roen']
# rose: ['roes']
# rowe: ['wroe']
# rube: ['rueb']
# rubel: ['ruble']
# ruble: ['rubel']
# ruckel: ['ruckle']
# ruckle: ['ruckel']
# rueb: ['rube']
# ruef: ['rufe']
# ruel: ['reul', 'rule']
# ruess: ['reuss']
# ruest: ['reust']
# rufe: ['ruef']
# rule: ['reul', 'ruel']
# rumpel: ['rumple']
# rumple: ['rumpel']
# runkel: ['runkle']
# runkle: ['runkel']
# saber: ['sabre']
# sabers: ['sabres']
# sabertech: ['sabretech']
# sabre: ['saber']
# sabres: ['sabers']
# sabretech: ['sabertech']
# samper: ['sampre']
# sampre: ['samper']
# saye: ['seay']
# schneider: ['schnieder']
# schneiders: ['schnieders']
# schnieder: ['schneider']
# schnieders: ['schneiders']
# schoen: ['schone']
# schone: ['schoen']
# seamen: ['seeman']
# seay: ['saye']
# seely: ['seley']
# seeman: ['seamen']
# seep: ['sepe']
# seers: ['seres']
# seid: ['side']
# seidl: ['sidle']
# seigal: ['siegal']
# seige: ['siege']
# seigel: ['seigle', 'siegel', 'siegle']
# seigle: ['seigel', 'siegel', 'siegle']
# seigler: ['siegler']
# seim: ['sime']
# sein: ['sine']
# seley: ['seely']
# sepe: ['seep']
# seres: ['seers']
# shankel: ['shankle']
# shankle: ['shankel']
# sheely: ['sheley']
# sheer: ['shere']
# shein: ['shine']
# sheley: ['sheely']
# shere: ['sheer']
# shine: ['shein']
# shu: ['hsu']
# sickel: ['sickle']
# sickels: ['sickles']
# sickle: ['sickel']
# sickles: ['sickels']
# side: ['seid']
# sidle: ['seidl']
# siegal: ['seigal']
# siege: ['seige']
# siegel: ['seigel', 'seigle', 'siegle']
# siegle: ['seigel', 'seigle', 'siegel']
# siegler: ['seigler']
# silvey: ['sylvie']
# sime: ['seim']
# sine: ['sein']
# singel: ['single']
# single: ['singel']
# sippel: ['sipple']
# sipple: ['sippel']
# skeen: ['skene']
# skene: ['skeen']
# sobel: ['soble']
# soble: ['sobel']
# soens: ['sones']
# sones: ['soens']
# specter: ['spectre']
# spectre: ['specter']
# spindel: ['spindle']
# spindle: ['spindel']
# sprinkel: ['sprinkle']
# sprinkle: ['sprinkel']
# squiers: ['squires']
# squires: ['squiers']
# stake: ['steak']
# stakes: ['steaks']
# stander: ['standre']
# standre: ['stander']
# steak: ['stake']
# steaks: ['stakes']
# steen: ['stene']
# steig: ['stieg']
# stein: ['stine']
# steinman: ['stineman']
# stempel: ['stemple']
# stemple: ['stempel']
# stene: ['steen']
# steuck: ['stueck']
# stickel: ['stickle']
# stickels: ['stickles']
# stickle: ['stickel']
# stickles: ['stickels']
# stieg: ['steig']
# stine: ['stein']
# stineman: ['steinman']
# stoeckel: ['stoeckle']
# stoeckle: ['stoeckel']
# streiber: ['strieber']
# streit: ['strite']
# strieber: ['streiber']
# strite: ['streit']
# strobel: ['stroble']
# stroble: ['strobel']
# strubel: ['struble']
# struble: ['strubel']
# stueck: ['steuck']
# swearengin: ['swearingen']
# swearingen: ['swearengin']
# sweet: ['swete']
# swete: ['sweet']
# sylvester: ['sylvestre']
# sylvestre: ['sylvester']
# sylvie: ['silvey']
# tempel: ['temple']
# temple: ['tempel']
# tengelmann: ['tenglemann']
# tenglemann: ['tengelmann']
# theaters: ['theatres']
# theatres: ['theaters']
# thoen: ['thone']
# thone: ['thoen']
# tide: ['tied']
# tied: ['tide']
# timber: ['timbre']
# timbre: ['timber']
# tindel: ['tindle']
# tindle: ['tindel']
# tittel: ['tittle']
# tittle: ['tittel']
# towel: ['towle']
# towle: ['towel']
# tracey: ['treacy']
# treacy: ['tracey']
# treu: ['true']
# trickel: ['trickle']
# trickle: ['trickel']
# trippel: ['tripple']
# tripple: ['trippel']
# true: ['treu']
# umbel: ['umble']
# umble: ['umbel']
# vanmeter: ['vanmetre']
# vanmetre: ['vanmeter']
# vansickel: ['vansickle']
# vansickle: ['vansickel']
# veer: ['vere']
# venter: ['ventre']
# venters: ['ventres']
# ventre: ['venter']
# ventres: ['venters']
# vere: ['veer']
# vide: ['vied']
# vied: ['vide']
# vowels: ['vowles']
# vowles: ['vowels']
# ware: ['wear']
# warehouse: ['wearhouse']
# wareing: ['wearing']
# wares: ['wears']
# wear: ['ware']
# wearhouse: ['warehouse']
# wearing: ['wareing']
# wears: ['wares']
# weber: ['webre']
# webre: ['weber']
# wehlan: ['whelan']
# weick: ['wieck']
# weidman: ['wideman']
# weigle: ['wiegel']
# weil: ['wile']
# weild: ['wield', 'wilde']
# wein: ['wien']
# weinberg: ['wineberg']
# weiner: ['wiener']
# weininger: ['wineinger']
# weinman: ['wineman']
# weins: ['wiens']
# whang: ['hwang']
# whelan: ['wehlan']
# wideman: ['weidman']
# wieck: ['weick']
# wiegel: ['weigle']
# wield: ['weild']
# wien: ['wein']
# wiener: ['weiner']
# wiens: ['weins']
# wies: ['wise']
# wilde: ['weild']
# wile: ['weil']
# wiley: ['wylie']
# willey: ['wyllie']
# wineberg: ['weinberg']
# wineinger: ['weininger']
# wineman: ['weinman']
# winkel: ['winkle']
# winkelman: ['winkleman']
# winkels: ['winkles']
# winkle: ['winkel']
# winkleman: ['winkelman']
# winkles: ['winkels']
# wise: ['wies']
# woelfel: ['woelfle']
# woelfle: ['woelfel']
# wojcik: ['wojick']
# wojick: ['wojcik']
# wroe: ['rowe']
# wylie: ['wiley']
# wyllie: ['willey']
# yates: ['yeats']
# yeakel: ['yeakle']

# %%
len(cmu_dict)
# Out:
# 123455

# %%
len(all_anagrams)
# Out:
# 32706

# %%
semantic_similar_anagrams
# Out:
# defaultdict(list,
#             {'accouterment': ['accoutrement'],
#              'accoutrement': ['accouterment'],
#              'amphitheater': ['amphitheatre'],
#              'amphitheatre': ['amphitheater'],
#              'angered': ['enraged'],
#              'ate': ['eat'],
#              'bate': ['beat'],
#              'beat': ['bate'],
#              'beats': ['baste'],
#              'being': ['begin'],
#              'casinos': ['cassino'],
#              'cats': ['cast'],
#              'cleaners': ['cleanser'],
#              'cleared': ['declare'],
#              'detail': ['dilate'],
#              'dilate': ['detail'],
#              'elections': ['selection'],
#              'elects': ['select'],
#              'enraged': ['angered'],
#              'fended': ['defend'],
#              'fiber': ['fibre'],
#              'fiberboard': ['fibreboard'],
#              'fibre': ['fiber'],
#              'fibreboard': ['fiberboard'],
#              'formed': ['deform'],
#              'hotels': ['hostel'],
#              'lookout': ['outlook'],
#              'luster': ['lustre'],
#              'lustre': ['luster'],
#              'mantel': ['mantle'],
#              'mantle': ['mantel'],
#              'mean': ['name'],
#              'miter': ['mitre'],
#              'mitre': ['miter'],
#              'name': ['mean'],
#              'nips': ['snip'],
#              'note': ['tone'],
#              'outlook': ['lookout'],
#              'overturn': ['turnover'],
#              'parental': ['paternal'],
#              'parted': ['depart'],
#              'pat': ['tap'],
#              'paternal': ['parental'],
#              'pates': ['paste'],
#              'posited': ['deposit'],
#              'post': ['spot'],
#              'punks': ['spunk'],
#              'recourse': ['resource'],
#              'resource': ['recourse'],
#              'roots': ['roost'],
#              'saber': ['sabre'],
#              'sabre': ['saber'],
#              'specter': ['spectre'],
#              'spectre': ['specter'],
#              'spot': ['post', 'stop'],
#              'stop': ['spot'],
#              'tap': ['pat'],
#              'timber': ['timbre'],
#              'timbre': ['timber'],
#              'tone': ['note'],
#              'tops': ['spot'],
#              'trees': ['steer'],
#              'turnover': ['overturn'],
#              'veto': ['vote'],
#              'vote': ['veto'],
#              'wells': ['swell']})

# %%
len(phonetic_similar_anagrams)
# Out:
# 968
